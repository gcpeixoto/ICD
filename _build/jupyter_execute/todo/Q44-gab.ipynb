# %% [markdown]
# ## Questionário Q44

# %% [markdown]
# Orientações:
#
# - Registre suas respostas no questionário de mesmo nome no SIGAA.
# - O tempo de registro das respostas no questionário será de 10 minutos. Portanto, resolva primeiro as questões e depois registre-as.
# - Haverá apenas 1 (uma) tentativa de resposta.
# - Submeta seu arquivo-fonte (utilizado para resolver as questões) em formato _.ipynb_ pelo SIGAA anexando-a à Tarefa denominada "Envio de arquivo" correspondente ao questionário.
#
# *Nota:* o arquivo-fonte será utilizado apenas como prova de execução da tarefa. Nenhuma avaliação será feita quanto ao estilo de programação.
#
# <hr>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import scipy as sp
np.set_printoptions(suppress=True)

# %% [markdown]
# **Questão 1.** O _dataset_ [covid19-weekly-trends-in-europe](https://github.com/gcpeixoto/ICD/blob/main/database/covid19-weekly-trends-in-europe.csv) contém tendências semanais de casos de Covid-19 em diferentes países da Europa com referência ao dia 8 de novembro de 2021. Separe a série correspondente ao número de casos nos últimos 7 dias (_Cases in the last 7 days_) entre países pertencentes à União Europeia (_UE_) e não pertencentes à UE (_non-UE_). Assinale a alternativa que associa corretamente o grupo de países ao valor do coeficiente de Pearson.
#
# A. _non-UE_: 620983827.08
#
# B. _UE_: 620983827.08
#
# C. _UE_: 750983827.02
#
# D. _non-UE_: 8290903184.71

# %% [markdown]
# <hr>
#
# ## Gabarito
#
# Alternativa **D**

# %% [markdown]
# This Dataset contains Weekly trends of COVID-19 in different regions of Europe as on November 08, 2021.

# %%
db = pd.read_csv("COVID-19_WEEKLY_TRENDS_IN_EUROPE.csv")
db = db.set_index("Country, Other")
db
# Out:
#                         Cases in the last 7 days  \
# Country, Other
# Russia                                    281305
# UK                                        245052
# Germany                                   172611
# Ukraine                                   153131
# Poland                                     78963
# Netherlands                                68958
# Romania                                    58851
# Czechia                                    53152
# Austria                                    52906
# France                                     50607
# Belgium                                    46581
# Greece                                     42734
# Serbia                                     40276
# Italy                                      36082
# Slovakia                                   34862
# Croatia                                    30979
# Bulgaria                                   30270
# Hungary                                    28745
# Ireland                                    23792
# Slovenia                                   20128
# Lithuania                                  18391
# Switzerland                                14892
# Denmark                                    14778
# Belarus                                    13759
# Latvia                                     12685
# Spain                                      11581
# Estonia                                    11127
# Norway                                      9575
# Moldova                                     8196
# Portugal                                    6906
# Finland                                     4945
# Montenegro                                  4265
# Albania                                     3825
# North Macedonia                             3525
# Sweden                                      3466
# Bosnia and Herzegovina                      3355
# Luxembourg                                  1159
# Channel Islands                              614
# Iceland                                      583
# Faeroe Islands                               470
# Isle of Man                                  279
# Malta                                        251
# Gibraltar                                    161
# Andorra                                      102
# Liechtenstein                                 81
# San Marino                                    60
# Monaco                                        21
#
#                         Cases in the preceding 7 days  Weekly Case % Change  \
# Country, Other
# Russia                                         272147                   3.0
# UK                                             281168                 -13.0
# Germany                                        131880                  31.0
# Ukraine                                        152897                   0.2
# Poland                                          52327                  51.0
# Netherlands                                     49489                  39.0
# Romania                                         86103                 -32.0
# Czechia                                         33393                  59.0
# Austria                                         32375                  63.0
# France                                          41009                  23.0
# Belgium                                         50270                  -7.0
# Greece                                          25812                  66.0
# Serbia                                          44540                 -10.0
# Italy                                           30780                  17.0
# Slovakia                                        27335                  28.0
# Croatia                                         25023                  24.0
# Bulgaria                                        33049                  -8.0
# Hungary                                         19594                  47.0
# Ireland                                         15717                  51.0
# Slovenia                                        15938                  26.0
# Lithuania                                       20506                 -10.0
# Switzerland                                     10144                  47.0
# Denmark                                         11369                  30.0
# Belarus                                         13934                  -1.0
# Latvia                                          16566                 -23.0
# Spain                                           13336                 -13.0
# Estonia                                         11931                  -7.0
# Norway                                           6763                  42.0
# Moldova                                          9768                 -16.0
# Portugal                                         5513                  25.0
# Finland                                          4375                  13.0
# Montenegro                                       3392                  26.0
# Albania                                          3604                   6.0
# North Macedonia                                  2786                  27.0
# Sweden                                           5920                 -41.0
# Bosnia and Herzegovina                           5083                 -34.0
# Luxembourg                                       1080                   7.0
# Channel Islands                                   476                  29.0
# Iceland                                           605                  -4.0
# Faeroe Islands                                    530                 -11.0
# Isle of Man                                       494                 -44.0
# Malta                                             102                 146.0
# Gibraltar                                         118                  36.0
# Andorra                                           112                  -9.0
# Liechtenstein                                      47                  72.0
# San Marino                                         34                  76.0
# Monaco                                             27                 -22.0
#
#                         Cases in the last 7 days/1M pop  \
# Country, Other
# Russia                                             1926
# UK                                                 3584
# Germany                                            2051
# Ukraine                                            3530
# Poland                                             2089
# Netherlands                                        4012
# Romania                                            3087
# Czechia                                            4951
# Austria                                            5829
# France                                              773
# Belgium                                            3996
# Greece                                             4127
# Serbia                                             4635
# Italy                                               598
# Slovakia                                           6381
# Croatia                                            7610
# Bulgaria                                           4401
# Hungary                                            2986
# Ireland                                            4747
# Slovenia                                           9680
# Lithuania                                          6886
# Switzerland                                        1704
# Denmark                                            2539
# Belarus                                            1457
# Latvia                                             6827
# Spain                                               248
# Estonia                                            8380
# Norway                                             1748
# Moldova                                            2038
# Portugal                                            680
# Finland                                             891
# Montenegro                                         6790
# Albania                                            1331
# North Macedonia                                    1692
# Sweden                                              340
# Bosnia and Herzegovina                             1031
# Luxembourg                                         1812
# Channel Islands                                    3488
# Iceland                                            1694
# Faeroe Islands                                     9570
# Isle of Man                                        3258
# Malta                                               566
# Gibraltar                                          4781
# Andorra                                            1317
# Liechtenstein                                      2116
# San Marino                                         1763
# Monaco                                              530
#
#                         Deaths in the last 7 days  \
# Country, Other
# Russia                                       8276
# UK                                           1173
# Germany                                       800
# Ukraine                                      4355
# Poland                                        758
# Netherlands                                   150
# Romania                                      2901
# Czechia                                       243
# Austria                                       145
# France                                        227
# Belgium                                       123
# Greece                                        357
# Serbia                                        450
# Italy                                         291
# Slovakia                                      195
# Croatia                                       280
# Bulgaria                                     1075
# Hungary                                       455
# Ireland                                        56
# Slovenia                                       85
# Lithuania                                     231
# Switzerland                                    43
# Denmark                                        24
# Belarus                                       114
# Latvia                                        246
# Spain                                         108
# Estonia                                        79
# Norway                                         22
# Moldova                                       309
# Portugal                                       46
# Finland                                        26
# Montenegro                                     45
# Albania                                        31
# North Macedonia                               100
# Sweden                                         10
# Bosnia and Herzegovina                        151
# Luxembourg                                      6
# Channel Islands                                 0
# Iceland                                         1
# Faeroe Islands                                  3
# Isle of Man                                     3
# Malta                                           1
# Gibraltar                                       0
# Andorra                                         0
# Liechtenstein                                   0
# San Marino                                      0
# Monaco                                          0
#
#                         Deaths in the preceeding 7 days  \
# Country, Other
# Russia                                             7938
# UK                                                 1099
# Germany                                             465
# Ukraine                                            3857
# Poland                                              552
# Netherlands                                          97
# Romania                                            3058
# Czechia                                             149
# Austria                                             106
# France                                              216
# Belgium                                             147
# Greece                                              310
# Serbia                                              446
# Italy                                               274
# Slovakia                                            131
# Croatia                                             182
# Bulgaria                                            926
# Hungary                                             237
# Ireland                                              67
# Slovenia                                             62
# Lithuania                                           244
# Switzerland                                          41
# Denmark                                              15
# Belarus                                             116
# Latvia                                              225
# Spain                                               228
# Estonia                                              70
# Norway                                                6
# Moldova                                             293
# Portugal                                             24
# Finland                                              19
# Montenegro                                           38
# Albania                                              50
# North Macedonia                                      81
# Sweden                                               20
# Bosnia and Herzegovina                              201
# Luxembourg                                            1
# Channel Islands                                       1
# Iceland                                               0
# Faeroe Islands                                        0
# Isle of Man                                           0
# Malta                                                 1
# Gibraltar                                             0
# Andorra                                               0
# Liechtenstein                                         1
# San Marino                                            1
# Monaco                                                0
#
#                         Weekly Death % Change  \
# Country, Other
# Russia                                    4.0
# UK                                        7.0
# Germany                                  72.0
# Ukraine                                  13.0
# Poland                                   37.0
# Netherlands                              55.0
# Romania                                  -5.0
# Czechia                                  63.0
# Austria                                  37.0
# France                                    5.0
# Belgium                                 -16.0
# Greece                                   15.0
# Serbia                                    1.0
# Italy                                     6.0
# Slovakia                                 49.0
# Croatia                                  54.0
# Bulgaria                                 16.0
# Hungary                                  92.0
# Ireland                                 -16.0
# Slovenia                                 37.0
# Lithuania                                -5.0
# Switzerland                               5.0
# Denmark                                  60.0
# Belarus                                  -2.0
# Latvia                                    9.0
# Spain                                   -53.0
# Estonia                                  13.0
# Norway                                  267.0
# Moldova                                   5.0
# Portugal                                 92.0
# Finland                                  37.0
# Montenegro                               18.0
# Albania                                 -38.0
# North Macedonia                          23.0
# Sweden                                  -50.0
# Bosnia and Herzegovina                  -25.0
# Luxembourg                              500.0
# Channel Islands                        -100.0
# Iceland                                 100.0
# Faeroe Islands                          300.0
# Isle of Man                             300.0
# Malta                                     0.0
# Gibraltar                                 0.0
# Andorra                                   0.0
# Liechtenstein                          -100.0
# San Marino                             -100.0
# Monaco                                    0.0
#
#                         Deaths in the last 7 days/1M pop  Population
# Country, Other
# Russia                                                57   146018963
# UK                                                    17    68367364
# Germany                                               10    84145628
# Ukraine                                              100    43378803
# Poland                                                20    37790630
# Netherlands                                            9    17186062
# Romania                                              152    19064310
# Czechia                                               23    10735806
# Austria                                               16     9075760
# France                                                 3    65468526
# Belgium                                               11    11657712
# Greece                                                34    10354278
# Serbia                                                52     8689831
# Italy                                                  5    60341753
# Slovakia                                              36     5463213
# Croatia                                               69     4071065
# Bulgaria                                             156     6877774
# Hungary                                               47     9627220
# Ireland                                               11     5012190
# Slovenia                                              41     2079324
# Lithuania                                             86     2670951
# Switzerland                                            5     8740037
# Denmark                                                4     5819739
# Belarus                                               12     9445126
# Latvia                                               132     1858017
# Spain                                                  2    46779233
# Estonia                                               59     1327740
# Norway                                                 4     5478446
# Moldova                                               77     4021300
# Portugal                                               5    10156551
# Finland                                                5     5552342
# Montenegro                                            72      628173
# Albania                                               11     2873553
# North Macedonia                                       48     2083258
# Sweden                                                 1    10184260
# Bosnia and Herzegovina                                46     3253249
# Luxembourg                                             9      639707
# Channel Islands                                        0      176025
# Iceland                                                3      344232
# Faeroe Islands                                        61       49114
# Isle of Man                                           35       85640
# Malta                                                  2      443131
# Gibraltar                                              0       33677
# Andorra                                                0       77432
# Liechtenstein                                          0       38276
# San Marino                                             0       34027
# Monaco                                                 0       39617

# %%
UE = pd.read_html("https://en.wikipedia.org/wiki/List_of_European_Union_member_states_by_population")
UE = UE[0].dropna()
UE
# Out:
#     Rank         Country  2020Eurostat figure[1]  % ofpop.  \
# 0    1.0         Germany                83166711     18.59
# 1    2.0          France                67320216     15.05
# 2    3.0           Italy                59641488     13.33
# 3    4.0           Spain                47332614     10.58
# 4    5.0          Poland                37958138      8.49
# 5    6.0         Romania                19328838      4.32
# 6    7.0     Netherlands                17407585      3.89
# 7    8.0         Belgium                11522440      2.58
# 8    9.0          Greece                10718565      2.40
# 9   10.0  Czech Republic                10693939      2.39
# 10  11.0          Sweden                10327589      2.31
# 11  12.0        Portugal                10295909      2.30
# 12  13.0         Hungary                 9769526      2.18
# 13  14.0         Austria                 8901064      1.99
# 14  15.0        Bulgaria                 6951482      1.55
# 15  16.0         Denmark                 5822763      1.30
# 16  17.0         Finland                 5525292      1.24
# 17  18.0        Slovakia                 5457873      1.22
# 18  19.0         Ireland                 4964440      1.11
# 19  20.0         Croatia                 4058165      0.91
# 20  21.0       Lithuania                 2794090      0.62
# 21  22.0        Slovenia                 2095861      0.47
# 22  23.0          Latvia                 1907675      0.43
# 23  24.0         Estonia                 1328976      0.30
# 24  25.0          Cyprus                  888005      0.20
# 25  26.0      Luxembourg                  626108      0.14
# 26  27.0           Malta                  514564      0.12
#
#     Nationalofficial figure Date of nationalofficial figure  \
# 0                83129285.0                   June 30, 2021
# 1                67399000.0                     March, 2021
# 2                60391000.0                 January 1, 2020
# 3                47351567.0                    July 1, 2020
# 4                38230000.0               February 28, 2021
# 5                19318000.0                 January 1, 2020
# 6                17475908.0                February 1, 2021
# 7                11560220.0                   March 1, 2021
# 8                10718565.0                 January 1, 2020
# 9                10701777.0               December 31, 2020
# 10               10379285.0               December 31, 2020
# 11               10295909.0                            2019
# 12                9730000.0                 January 1, 2021
# 13                8901064.0                 January 1, 2020
# 14                6916548.0               December 31, 2020
# 15                5840045.0                 January 1, 2021
# 16                5537116.0                  March 31, 2021
# 17                5459781.0               December 31, 2020
# 18                4977400.0                   April 1, 2020
# 19                4047200.0               December 31, 2020
# 20                2785501.0                     May 1, 2021
# 21                2108977.0                 January 1, 2021
# 22                1887600.0                   April 1, 2021
# 23                1330068.0                 January 1, 2021
# 24                 888000.0               December 31, 2019
# 25                 634700.0                 January 1, 2021
# 26                 514564.0               December 31, 2019
#
#    Source of nationalofficial figure
# 0                  Official estimate
# 1          Monthly official estimate
# 2          Monthly official estimate
# 3                  Official estimate
# 4                  Official estimate
# 5                  Official estimate
# 6          Monthly official estimate
# 7          Monthly official estimate
# 8                  Official estimate
# 9                  Official estimate
# 10         Monthly official estimate
# 11                 Official estimate
# 12                 Official estimate
# 13                 Official estimate
# 14                 Official estimate
# 15                 Official estimate
# 16         Monthly official estimate
# 17                 Official estimate
# 18                 Official estimate
# 19                 Official estimate
# 20         Monthly official estimate
# 21                 Official estimate
# 22         Monthly official estimate
# 23                 Official estimate
# 24                 Official estimate
# 25                 Official estimate
# 26                 Official estimate

# %%
#Tem que tratar pois não tem Cyprus no nosso dataset
UE_ = []
out_UE = []
db.index
for i in db.index:
    if i in UE["Country"].values:
        
        UE_.append(i)
    else:
        out_UE.append(i)

# %%
#lista de poíses da união européia presente no dataset
UE_
# Out:
# ['Germany',
#  'Poland',
#  'Netherlands',
#  'Romania',
#  'Austria',
#  'France',
#  'Belgium',
#  'Greece',
#  'Italy',
#  'Slovakia',
#  'Croatia',
#  'Bulgaria',
#  'Hungary',
#  'Ireland',
#  'Slovenia',
#  'Lithuania',
#  'Denmark',
#  'Latvia',
#  'Spain',
#  'Estonia',
#  'Portugal',
#  'Finland',
#  'Sweden',
#  'Luxembourg',
#  'Malta']

# %%
#Paises que estão no nosso dataset mas não são da União européia
out_UE
# Out:
# ['Russia',
#  'UK',
#  'Ukraine',
#  'Czechia',
#  'Serbia',
#  'Switzerland',
#  'Belarus',
#  'Norway',
#  'Moldova',
#  'Montenegro',
#  'Albania',
#  'North Macedonia',
#  'Bosnia and Herzegovina',
#  'Channel Islands',
#  'Iceland',
#  'Faeroe Islands',
#  'Isle of Man',
#  'Gibraltar',
#  'Andorra',
#  'Liechtenstein',
#  'San Marino',
#  'Monaco']

# %%
UE_db = db.loc[UE_]
out_UE_db = db.loc[out_UE]

# %%
# coeficiente de pearson
def p(x):
    return 3*( x.mean() - x.median() )*x.std()

# %%
pp = np.array([p(UE_db['Cases in the last 7 days']), p(out_UE_db['Cases in the last 7 days'])])

p_list = ['Dentro da União Europeia', 'Fora da União Européia']

p_list[np.argmax(pp)],pp
# Out:
# ('Fora da União Européia', array([6.20983827e+08, 8.29090318e+09]))

# %%
f'Resposta esperada: {p_list[np.argmax(pp)]} //{pp.max()}'
# Out:
# 'Resposta esperada: Fora da União Européia //8290903184.710569'

# %% [markdown]
# <hr>
#
# **Questão 2.** Analise as seguintes distribuições normais aleatórias:
#
# ```{figure} ../figs/q/q-44-1.png
# ---
# width: 400px
# name: q44-1
# ---
# ```
#
# Assinale a alternativa em que as curvas aparecem em ordem crescente de desvio padrão.
#
# A. (A, B, C, D)
#
# B. (B, A, D, C)
#
# C. (B, A, C, D)
#
# D. (A, B, D, C)

# %% [markdown]
# <hr>
#
# ## Gabarito
# Alternativa **C**
#
# ## LEMBRAR DE CONFERIR O GABARITO DESSA QUESTÃO PROFESSOR

# %%
plt.figure(figsize = (10,5))
#distribuições

dn1 = sp.random.normal(2,10,300);
dn2 = sp.random.normal(-20,5,300);
dn3 = sp.random.normal(40,40,300);
dn4 = sp.random.normal(100,27,300);

#mu = 2 // sigma = 10
count, bins, ignored = plt.hist(dn1, 30, density=True, alpha=0.5,label = 'Curva A')
plt.plot(bins, 1/(10 * np.sqrt(2 * np.pi)) * np.exp( - (bins - 2)**2 / (2 * 10**2) ),linewidth=1.5, color='b')


#mu = -20 // sigma = 5
count, bins, ignored = plt.hist(dn2, 30, density=True, alpha=0.5,label = 'Curva B')
plt.plot(bins, 1/(5 * np.sqrt(2 * np.pi)) * np.exp( - (bins - (-20))**2 / (2 * 5**2) ),linewidth=1.5, color='orange')


#mu = 40 // sigma = 40
count, bins, ignored = plt.hist(dn3, 30, density=True, alpha=0.5, label = 'Curva C')
plt.plot(bins, 1/(40 * np.sqrt(2 * np.pi)) * np.exp( - (bins - 40)**2 / (2 * 40**2) ),linewidth=1.5, color='g')

#mu = 100 // sigma = 27
count, bins, ignored = plt.hist(dn4, 30, density=True, alpha=0.5, label = 'Curva D')
plt.plot(bins, 1/(27 * np.sqrt(2 * np.pi)) * np.exp( - (bins - 100)**2 / (2 * 27**2) ),linewidth=1.5, color='r')

plt.legend(loc=1);
plt.xticks([])
plt.yticks([-10])
#plt.savefig('../figs/q/q44-1.png')

# %%
sum(dn3)>sum(dn4)
# Out:
# False

# %% [markdown]
# <hr>
#
# **Questão 3.** O código
#
# ```python
# import numpy as np, from scipy.stats import norm
# N, band = 100, 0.5
#
# np.random.seed(2)
# X = np.concatenate(
#     (np.random.normal(0, 1, int(0.3 * N)),
#      np.random.normal(5, 1, int(0.7 * N))))[:, np.newaxis]
# Xp = np.linspace(-5, 10, 1000)[:, np.newaxis]
#
# dens = 0.3*norm(0,1).pdf(Xp[:, 0]) + 0.7*norm(5,1).pdf(Xp[:, 0])
# ```
# gera a distribuição sombreada `dens` apresentada nas figuras de (a) a (d) abaixo.
#
# ```{figure} ../figs/q/q-44-2.png
# ---
# width: 400px
# name: q44-2
# ---
# ```
# Com base nos _kernels_ disponíveis na classe `KernelDensity`
# do módulo _scikit-learn_, assinale a alternativa que melhor preeche as lacunas na sentença:
#
# *"O kernel ______ aproxima a distribuição em ______, ao passo que o kernel ______ aproxima a distribuição mostrada em ______."*
#
#
# A. 'linear' / (a) / 'gaussian' / (d)
#
# B. 'linear' / (b) / 'tophat' / (a)
#
# C. 'epanechnikov' / (c) / 'linear' / (d)
#
# D. 'gaussian' / (b) / 'epanechnikov' / (c)

# %% [markdown]
# <hr>
#
# ## Gabarito
#
# Alternativa **C**

# %%
from sklearn.neighbors import KernelDensity
from scipy.stats import norm
N = 100 # amostras
band = 0.5 # largura de banda

np.random.seed(2)
X = np.concatenate(
    (np.random.normal(0, 1, int(0.3 * N)),
     np.random.normal(5, 1, int(0.7 * N))))[:, np.newaxis]
Xp = np.linspace(-5, 10, 1000)[:, np.newaxis]

true_dens = 0.3 * norm(0,1).pdf(Xp[:, 0]) + 0.7 * norm(5, 1).pdf(Xp[:, 0])

# gaussian
kde_gaus = KernelDensity(kernel='gaussian', bandwidth=band).fit(X)
log_dens_gaus = kde_gaus.score_samples(Xp)

# tophat
kde_tophat = KernelDensity(kernel='tophat', bandwidth=band).fit(X)
log_dens_tophat = kde_tophat.score_samples(Xp)

# epanechnikov
kde_epanechnikov = KernelDensity(kernel='epanechnikov', bandwidth=band).fit(X)
log_dens_epanechnikov = kde_epanechnikov.score_samples(Xp)

# linear
kde_linear = KernelDensity(kernel='linear', bandwidth=band).fit(X)
log_dens_linear = kde_linear.score_samples(Xp)

plt.subplot(221)
plt.fill_between(Xp[:,0],true_dens,alpha=0.3)
plt.plot(Xp[:,0],np.exp(log_dens_gaus),c='#ed3411')
plt.xticks([]); plt.yticks([]);
plt.title('(a)')

plt.subplot(222)
plt.fill_between(Xp[:,0],true_dens,alpha=0.3)
plt.plot(Xp[:,0],np.exp(log_dens_tophat),c='#ed3411')
plt.xticks([]); plt.yticks([]);
plt.title('(b)')

plt.subplot(223)
plt.fill_between(Xp[:,0],true_dens,alpha=0.3)
plt.plot(Xp[:,0],np.exp(log_dens_epanechnikov),c='#ed3411')
plt.xticks([]); plt.yticks([]);
plt.title('(c)')

plt.subplot(224)
plt.fill_between(Xp[:,0],true_dens,alpha=0.3)
plt.plot(Xp[:,0],np.exp(log_dens_linear),c='#ed3411')
plt.xticks([]); plt.yticks([-10]);
plt.title('(d)');
#plt.savefig('../figs/q/q44-2.png')
