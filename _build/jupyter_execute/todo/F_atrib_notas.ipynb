# %% [markdown]
# ## Algoritmo de avaliação personalizado (ICD)
#
# Lucas Miranda de Aguiar

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ##### Alunos Ativos no SIGAA (em ordem alfabética)

# %%
alunos = pd.read_excel("notas_GDCOC0089_T01_20211.xls")

# %%
matriculas_alun = ["20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL", "20200111286 - ÂNGELA THAÍS ALVES DA SILVA",
                   "20200026560 - CLELIO SANDOVAL DA FONSECA", "20190035175 - FRANCELINO TEOTONIO JUNIOR",
                   "20200112309 - GABRIEL BARBOSA FERRAZ JARDIM", "20200026247 - GUILHERME HERCULANO FERNANDES",
                   "20200161250 - GUILHERME IRAM SILVA ARAUJO", "20200114706 - GUILHERME PUJONI MENEZES",
                   "20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE", "20200154050 - INGRID DAYANE DA SILVA FERREIRA",
                   "20200024162 - ISMAEL ALVES LIMA", "20200139170 - JANSEN CRUZ DE SOUZA",
                   "20200088188 - JOSUE CALEB AVELINO DOS SANTOS","20190033519 - KENYO MAILTON DA SILVA OLIVEIRA",
                   "20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO", "20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA",
                   "11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBRINHO", "20200133309  - MARCOS DANTAS GUIMARAES FILHO",
                   "20200026200 - MARIA IARA DE ARAUJO", "20200025900 - MARIA RAQUEL SOUZA MARTINEZ",
                   "20170052034 - MARIANA FRANZ MARROQUIM","20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL",
                   "11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI", "20200026327 - RENAN CAVALCANTI FLORENTINO",
                   "20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO", "20180034639 - SAULO DE ALMEIDA ATAIDE NETO",
                   "20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA", "20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA",
                   "20200116827 - WEDSON CHAVES DE SOUSA", "20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA"]

# %% [markdown]
# ##### Criação do DataFrame, todos os valores precisam começar com 0 e posteriormente vai modificando de acordo com a nota do aluno

# %%
#Ta com notas random apenas para testes.

notas = pd.DataFrame({"A2": [random.randint(0,10)], "Q21":[random.randint(0,10)],"Q22":[random.randint(0,10)],"Q23":[random.randint(0,10)],"Q24":[random.randint(0,10)],"Q25":[random.randint(0,10)]},index = matriculas_alun)

# %%
notas["A3"]  = 0
notas["Q31"] = 0
notas["Q32"] = 0

notas["A4"]  = 0
notas["Q41"] = 0
notas["Q42"] = 0
notas["Q43"] = 0
notas["Q44"] = 0

notas["A5"]  = 0
notas["Q51"] = 0
notas["Q52"] = 0

notas["A6"]  = 0
notas["Q61"] = 0
notas["Q62"] = 0

notas["A7"]  = 0
notas["Q71"] = 0
notas["Q72"] = 0
notas["Q73"] = 0
notas["Q74"] = 0

# %% [markdown]
# #### Função para inserção de notas

# %%
def insere(df):
    ## dados do aluno para modificação das notas
    aluno = input("Insira a matrícula: ")
    aluno = aluno + " - " + input("Insira o nome completo: ").upper()
    alvo = input("Qual atividade será atribuida nota? (Ex: Q32) ")
    nota = float(input("Insira a nota do aluno para essa atividade: "))
    
    #contador para alterar valores em lista
    count = 0
    #criando nova lista pra modificar o dataset
    lista = np.ones(len(df[alvo]))
    
    #modificando nota específica
    for x,y in df[alvo].items():
        if x == aluno:
            lista[count] = lista[count]*nota
        else:
            lista[count] = lista[count]*y
        
        count+=1
           
    df[alvo] = lista
    return df

# %% [markdown]
# Inserindo a nota do A2 em Francelino

# %%
insere(notas);notas
# Out:
# Insira a matrícula: 20190035175
# Insira o nome completo: FRANCELINO TEOTONIO JUNIOR
# Qual atividade será atribuida nota? (Ex: Q32) A2
# Insira a nota do aluno para essa atividade: 8.4
#                                                      A2  Q21  Q22  Q23  Q24  \
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL   3.0    3   10   10    7
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA           3.0    3   10   10    7
# 20200026560 - CLELIO SANDOVAL DA FONSECA            3.0    3   10   10    7
# 20190035175 - FRANCELINO TEOTONIO JUNIOR            8.4    3   10   10    7
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM         3.0    3   10   10    7
# 20200026247 - GUILHERME HERCULANO FERNANDES         3.0    3   10   10    7
# 20200161250 - GUILHERME IRAM SILVA ARAUJO           3.0    3   10   10    7
# 20200114706 - GUILHERME PUJONI MENEZES              3.0    3   10   10    7
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE       3.0    3   10   10    7
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA       3.0    3   10   10    7
# 20200024162 - ISMAEL ALVES LIMA                     3.0    3   10   10    7
# 20200139170 - JANSEN CRUZ DE SOUZA                  3.0    3   10   10    7
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS        3.0    3   10   10    7
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA       3.0    3   10   10    7
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO         3.0    3   10   10    7
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA         3.0    3   10   10    7
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...  3.0    3   10   10    7
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO        3.0    3   10   10    7
# 20200026200 - MARIA IARA DE ARAUJO                  3.0    3   10   10    7
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ           3.0    3   10   10    7
# 20170052034 - MARIANA FRANZ MARROQUIM               3.0    3   10   10    7
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL     3.0    3   10   10    7
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI      3.0    3   10   10    7
# 20200026327 - RENAN CAVALCANTI FLORENTINO           3.0    3   10   10    7
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO   3.0    3   10   10    7
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO          3.0    3   10   10    7
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA    3.0    3   10   10    7
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA      3.0    3   10   10    7
# 20200116827 - WEDSON CHAVES DE SOUSA                3.0    3   10   10    7
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA     3.0    3   10   10    7
#
#                                                     Q25  A3  Q31  Q32  A4  \
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL     6   0    0    0   0
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA             6   0    0    0   0
# 20200026560 - CLELIO SANDOVAL DA FONSECA              6   0    0    0   0
# 20190035175 - FRANCELINO TEOTONIO JUNIOR              6   0    0    0   0
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM           6   0    0    0   0
# 20200026247 - GUILHERME HERCULANO FERNANDES           6   0    0    0   0
# 20200161250 - GUILHERME IRAM SILVA ARAUJO             6   0    0    0   0
# 20200114706 - GUILHERME PUJONI MENEZES                6   0    0    0   0
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE         6   0    0    0   0
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA         6   0    0    0   0
# 20200024162 - ISMAEL ALVES LIMA                       6   0    0    0   0
# 20200139170 - JANSEN CRUZ DE SOUZA                    6   0    0    0   0
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS          6   0    0    0   0
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA         6   0    0    0   0
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO           6   0    0    0   0
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA           6   0    0    0   0
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...    6   0    0    0   0
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO          6   0    0    0   0
# 20200026200 - MARIA IARA DE ARAUJO                    6   0    0    0   0
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ             6   0    0    0   0
# 20170052034 - MARIANA FRANZ MARROQUIM                 6   0    0    0   0
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL       6   0    0    0   0
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI        6   0    0    0   0
# 20200026327 - RENAN CAVALCANTI FLORENTINO             6   0    0    0   0
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO     6   0    0    0   0
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO            6   0    0    0   0
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA      6   0    0    0   0
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA        6   0    0    0   0
# 20200116827 - WEDSON CHAVES DE SOUSA                  6   0    0    0   0
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA       6   0    0    0   0
#
#                                                     ...  Q51  Q52  A6  Q61  \
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL   ...    0    0   0    0
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA           ...    0    0   0    0
# 20200026560 - CLELIO SANDOVAL DA FONSECA            ...    0    0   0    0
# 20190035175 - FRANCELINO TEOTONIO JUNIOR            ...    0    0   0    0
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM         ...    0    0   0    0
# 20200026247 - GUILHERME HERCULANO FERNANDES         ...    0    0   0    0
# 20200161250 - GUILHERME IRAM SILVA ARAUJO           ...    0    0   0    0
# 20200114706 - GUILHERME PUJONI MENEZES              ...    0    0   0    0
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE       ...    0    0   0    0
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA       ...    0    0   0    0
# 20200024162 - ISMAEL ALVES LIMA                     ...    0    0   0    0
# 20200139170 - JANSEN CRUZ DE SOUZA                  ...    0    0   0    0
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS        ...    0    0   0    0
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA       ...    0    0   0    0
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO         ...    0    0   0    0
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA         ...    0    0   0    0
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...  ...    0    0   0    0
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO        ...    0    0   0    0
# 20200026200 - MARIA IARA DE ARAUJO                  ...    0    0   0    0
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ           ...    0    0   0    0
# 20170052034 - MARIANA FRANZ MARROQUIM               ...    0    0   0    0
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL     ...    0    0   0    0
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI      ...    0    0   0    0
# 20200026327 - RENAN CAVALCANTI FLORENTINO           ...    0    0   0    0
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO   ...    0    0   0    0
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO          ...    0    0   0    0
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA    ...    0    0   0    0
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA      ...    0    0   0    0
# 20200116827 - WEDSON CHAVES DE SOUSA                ...    0    0   0    0
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA     ...    0    0   0    0
#
#                                                     Q62  A7  Q71  Q72  Q73  \
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL     0   0    0    0    0
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA             0   0    0    0    0
# 20200026560 - CLELIO SANDOVAL DA FONSECA              0   0    0    0    0
# 20190035175 - FRANCELINO TEOTONIO JUNIOR              0   0    0    0    0
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM           0   0    0    0    0
# 20200026247 - GUILHERME HERCULANO FERNANDES           0   0    0    0    0
# 20200161250 - GUILHERME IRAM SILVA ARAUJO             0   0    0    0    0
# 20200114706 - GUILHERME PUJONI MENEZES                0   0    0    0    0
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE         0   0    0    0    0
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA         0   0    0    0    0
# 20200024162 - ISMAEL ALVES LIMA                       0   0    0    0    0
# 20200139170 - JANSEN CRUZ DE SOUZA                    0   0    0    0    0
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS          0   0    0    0    0
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA         0   0    0    0    0
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO           0   0    0    0    0
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA           0   0    0    0    0
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...    0   0    0    0    0
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO          0   0    0    0    0
# 20200026200 - MARIA IARA DE ARAUJO                    0   0    0    0    0
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ             0   0    0    0    0
# 20170052034 - MARIANA FRANZ MARROQUIM                 0   0    0    0    0
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL       0   0    0    0    0
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI        0   0    0    0    0
# 20200026327 - RENAN CAVALCANTI FLORENTINO             0   0    0    0    0
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO     0   0    0    0    0
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO            0   0    0    0    0
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA      0   0    0    0    0
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA        0   0    0    0    0
# 20200116827 - WEDSON CHAVES DE SOUSA                  0   0    0    0    0
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA       0   0    0    0    0
#
#                                                     Q74
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL     0
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA             0
# 20200026560 - CLELIO SANDOVAL DA FONSECA              0
# 20190035175 - FRANCELINO TEOTONIO JUNIOR              0
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM           0
# 20200026247 - GUILHERME HERCULANO FERNANDES           0
# 20200161250 - GUILHERME IRAM SILVA ARAUJO             0
# 20200114706 - GUILHERME PUJONI MENEZES                0
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE         0
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA         0
# 20200024162 - ISMAEL ALVES LIMA                       0
# 20200139170 - JANSEN CRUZ DE SOUZA                    0
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS          0
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA         0
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO           0
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA           0
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...    0
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO          0
# 20200026200 - MARIA IARA DE ARAUJO                    0
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ             0
# 20170052034 - MARIANA FRANZ MARROQUIM                 0
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL       0
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI        0
# 20200026327 - RENAN CAVALCANTI FLORENTINO             0
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO     0
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO            0
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA      0
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA        0
# 20200116827 - WEDSON CHAVES DE SOUSA                  0
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA       0
#
# [30 rows x 25 columns]

# %% [markdown]
# ## Nota das partes
#
# $$
# \begin{array}{rcl}
# N_p&=&0,5(A_p)+\sum_{i} x_i(Qpi)\\
#     \\
# \end{array}
# $$
# - p: parte
# - Qpi: questionário i da parte p
# - xi: peso do questionário Qpi (igual para todos os Qpi, obedecendo a soma 0,5)

# %%
#É preciso ir colocando as notas gradativamente, primeiro a parte 2, dps a parte 3...

def nota_partes(df):
    #Inserindo a parte
    parte = int(input("Inisira a parte: ")) 
    
    #Selecionando os questionários correspondentes a parte
    if parte == 2:
        Q = df.loc[:,["Q21","Q22","Q23","Q24","Q25"]]
    elif parte == 3:
        Q = df.loc[:,["Q31","Q32"]]
    elif parte == 4:
        Q = df.loc[:,["Q41","Q42","Q43","Q44"]]
    elif parte == 5:
        Q = df.loc[:,["Q51","Q52"]]
    elif parte == 6:
        Q = df.loc[:,["Q61","Q62"]]        
    elif parte == 7:
        Q = df.loc[:,["Q71","Q72","Q73","Q74"]]
    else:
        print("Parte inválida.")
        return 0
    
    #Formula da nota das partes 
    df["Parte "+str(parte)] = (0.5*df["A"+str(parte)])+(np.array([sum((0.5/len(Q.columns)) * Q.values[_]) for _ in range(len(Q))]))
    
    #retorna a matrícula, o nome e a nota da parte.
    return Q.join(df.loc[:,["A"+str(parte),"Parte "+str(parte)]])

# %% [markdown]
# Observe a nota de Francelino

# %%
nota_partes(notas)
# Out:
# Inisira a parte: 2
#                                                     Q21  Q22  Q23  Q24  Q25  \
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL     3   10   10    7    6
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA             3   10   10    7    6
# 20200026560 - CLELIO SANDOVAL DA FONSECA              3   10   10    7    6
# 20190035175 - FRANCELINO TEOTONIO JUNIOR              3   10   10    7    6
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM           3   10   10    7    6
# 20200026247 - GUILHERME HERCULANO FERNANDES           3   10   10    7    6
# 20200161250 - GUILHERME IRAM SILVA ARAUJO             3   10   10    7    6
# 20200114706 - GUILHERME PUJONI MENEZES                3   10   10    7    6
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE         3   10   10    7    6
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA         3   10   10    7    6
# 20200024162 - ISMAEL ALVES LIMA                       3   10   10    7    6
# 20200139170 - JANSEN CRUZ DE SOUZA                    3   10   10    7    6
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS          3   10   10    7    6
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA         3   10   10    7    6
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO           3   10   10    7    6
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA           3   10   10    7    6
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...    3   10   10    7    6
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO          3   10   10    7    6
# 20200026200 - MARIA IARA DE ARAUJO                    3   10   10    7    6
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ             3   10   10    7    6
# 20170052034 - MARIANA FRANZ MARROQUIM                 3   10   10    7    6
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL       3   10   10    7    6
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI        3   10   10    7    6
# 20200026327 - RENAN CAVALCANTI FLORENTINO             3   10   10    7    6
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO     3   10   10    7    6
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO            3   10   10    7    6
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA      3   10   10    7    6
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA        3   10   10    7    6
# 20200116827 - WEDSON CHAVES DE SOUSA                  3   10   10    7    6
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA       3   10   10    7    6
#
#                                                      A2  Parte 2
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL   3.0      5.1
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA           3.0      5.1
# 20200026560 - CLELIO SANDOVAL DA FONSECA            3.0      5.1
# 20190035175 - FRANCELINO TEOTONIO JUNIOR            8.4      7.8
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM         3.0      5.1
# 20200026247 - GUILHERME HERCULANO FERNANDES         3.0      5.1
# 20200161250 - GUILHERME IRAM SILVA ARAUJO           3.0      5.1
# 20200114706 - GUILHERME PUJONI MENEZES              3.0      5.1
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE       3.0      5.1
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA       3.0      5.1
# 20200024162 - ISMAEL ALVES LIMA                     3.0      5.1
# 20200139170 - JANSEN CRUZ DE SOUZA                  3.0      5.1
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS        3.0      5.1
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA       3.0      5.1
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO         3.0      5.1
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA         3.0      5.1
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...  3.0      5.1
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO        3.0      5.1
# 20200026200 - MARIA IARA DE ARAUJO                  3.0      5.1
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ           3.0      5.1
# 20170052034 - MARIANA FRANZ MARROQUIM               3.0      5.1
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL     3.0      5.1
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI      3.0      5.1
# 20200026327 - RENAN CAVALCANTI FLORENTINO           3.0      5.1
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO   3.0      5.1
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO          3.0      5.1
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA    3.0      5.1
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA      3.0      5.1
# 20200116827 - WEDSON CHAVES DE SOUSA                3.0      5.1
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA     3.0      5.1

# %% [markdown]
# ## Nota das unidades
#
# $$
# \begin{array}{rcl}
# N_u&=&\frac{1}{P}*\sum_{p=1}^p N_p\\
#     \\
# \end{array}
# $$
# - u: unidade
# - Np: nota da parte
# - P: numero de partes

# %%
def nota_unidade(df):
    #Inserindo a unidade
    unidade = int(input("Inisira a unidade: ")) 
    
    #Selecionando a parte correspondente
    if unidade == 1:
        P = notas.loc[:,["Parte 2"]]
    elif unidade == 2:
        P = notas.loc[:,["Parte 3", "Parte 4"]]
    elif unidade == 3:
        P = df.loc[:,["Parte 5","Parte 6"]]
    elif unidade == 4:
        P = df.loc[:,["Parte 7"]]        
    else:
        print("Unidade inválida.")
        return 0
    
    #Formula da nota das partes            
    df["Und. "+str(unidade)] = (1/(len(P.columns)))*(np.array([sum(P.values[_]) for _ in range(len(P))]))
    
    return P.join(df.loc[:,["Und. "+str(unidade)]])

# %%
nota_unidade(notas)
# Out:
# Inisira a unidade: 1
#                                                     Parte 2  Und. 1
# 20180042677 - ANA PAULA CARDOSO DE CASTRO KENDALL       5.1     5.1
# 20200111286 - ÂNGELA THAÍS ALVES DA SILVA               5.1     5.1
# 20200026560 - CLELIO SANDOVAL DA FONSECA                5.1     5.1
# 20190035175 - FRANCELINO TEOTONIO JUNIOR                7.8     7.8
# 20200112309 - GABRIEL BARBOSA FERRAZ JARDIM             5.1     5.1
# 20200026247 - GUILHERME HERCULANO FERNANDES             5.1     5.1
# 20200161250 - GUILHERME IRAM SILVA ARAUJO               5.1     5.1
# 20200114706 - GUILHERME PUJONI MENEZES                  5.1     5.1
# 20190133775 - IKARO HENRIQUE MONTEIRO ANDRADE           5.1     5.1
# 20200154050 - INGRID DAYANE DA SILVA FERREIRA           5.1     5.1
# 20200024162 - ISMAEL ALVES LIMA                         5.1     5.1
# 20200139170 - JANSEN CRUZ DE SOUZA                      5.1     5.1
# 20200088188 - JOSUE CALEB AVELINO DOS SANTOS            5.1     5.1
# 20190033519 - KENYO MAILTON DA SILVA OLIVEIRA           5.1     5.1
# 20180116153 - LEANDRO QUEIROZ CIRINO ARAUJO             5.1     5.1
# 20190036379 - LUIS HENRIQUE AUGUSTO DE LIMA             5.1     5.1
# 11510431 - MANOEL CLEONALDO MENDES PEREIRA SOBR...      5.1     5.1
# 20200133309  - MARCOS DANTAS GUIMARAES FILHO            5.1     5.1
# 20200026200 - MARIA IARA DE ARAUJO                      5.1     5.1
# 20200025900 - MARIA RAQUEL SOUZA MARTINEZ               5.1     5.1
# 20170052034 - MARIANA FRANZ MARROQUIM                   5.1     5.1
# 20200025508 - MATHEUS VICTOR ALVES BRAGA MACIEL         5.1     5.1
# 11507225 - RAMON AZEVEDO DOS SANTOS CAVALCANTI          5.1     5.1
# 20200026327 - RENAN CAVALCANTI FLORENTINO               5.1     5.1
# 20180044519 - RHUAN GABRIEL DO NASCIMENTO GALDINO       5.1     5.1
# 20180034639 - SAULO DE ALMEIDA ATAIDE NETO              5.1     5.1
# 20200025983 - TALES NOBRE LEITE DIAS DE OLIVEIRA        5.1     5.1
# 20190145696 - VIVIANNY KHATLY MEDEIROS PEREIRA          5.1     5.1
# 20200116827 - WEDSON CHAVES DE SOUSA                    5.1     5.1
# 20200024583 - WILSON FILLIPE DO NASCIMENTO LIMA         5.1     5.1

# %% [markdown]
# ## Nota das FINAL
#
# $$
# \begin{array}{rcl}
# N_f&=&\sum_{u=1}^4 0,1N_u + 0,6 NPF\\
#     \\
# \end{array}
# $$
# - u: unidade
# - Nf: nota final
# - NPF: Nota do projeto final

# %%
notas["NPF"] = 0
#basta chamar a função insere(notas) e atribuir os valores do projeto final

# %%
def nota_final(df):
    n_u = df.loc[:,["Unid. 1","Unid. 1","Unid. 1","Unid. 1","Unid. 1"]]
    df['NotaFinal'] = 0.1*n_u.values + 0.6*df['NPF']
    return n_u.join(df.loc[:,['NotaFinal']])
